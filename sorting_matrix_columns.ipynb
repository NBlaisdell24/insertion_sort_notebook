# %% [markdown]
# <a href="https://colab.research.google.com/github/NBlaisdell24/insertion_sort_notebook/blob/main/sorting_matrix_columns.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Having fun with insertion sort

# %% [markdown]
# Import libraries

# %%
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import numpy as np

# %% [markdown]
# Create a matrix to represent the image

# %%
def createImage(nrows, ncols):
    # Create a matrix
    matrix = np.zeros((nrows, ncols))

    for i in range(nrows):
        for j in range(ncols):
            matrix[i,j] = (i+1)

    return matrix

# %% [markdown]
# Shuffle the values in the columns of the matrix

# %%
def shuffle_matrix(matrix):
    # Flatten the matrix
    flattened_matrix = matrix.flatten()

    # Shuffle the flattened matrix
    np.random.shuffle(flattened_matrix)

    # Reshape the matrix back to its original shape
    shuffled_matrix = flattened_matrix.reshape(matrix.shape)

    return shuffled_matrix

# %% [markdown]
# Sort the values in the columns of the matrix

# %%
def sort_columns(matrix):

    sorted_matrix = np.sort(matrix, axis=0)

    return sorted_matrix

# %% [markdown]
# Create the matrix and display

# %%
# Define the matrix size
nRows = 20
nCols = nRows

# Create a matrix to represent the image
matrix = createImage(nRows, nCols)

# Display the matrix as an image
plt.imshow(matrix, cmap='jet')
plt.colorbar()
plt.show()

# %% [markdown]
# Shuffle the values in the matrix columns

# %%
# Suffle the matrix values
shuffled_matrix = shuffle_matrix(matrix)

# Display suffled matrix as an image
plt.imshow(shuffled_matrix, cmap='jet')
plt.colorbar()
plt.show()

# %% [markdown]
# Sort columns to recover original matrix

# %%
# Sort each column to recover the original order
sorted_matrix = sort_columns(matrix)

# Display sorted matrix as an image
plt.imshow(sorted_matrix, cmap='jet')
plt.colorbar()
plt.show()

# %%
# My own Sorting Function

# %%
def insertion_sort(unsorted_array):
  sorted_array = unsorted_array

  return sorted_array

# %%
# My Function for Sorting the Columns
def sort_columns_insertion_sort(matrix):

  # Sort each column of the matrix

  # Get a column of the matrix (image) as an array

  # Call the sorting function to sort the array

  # Store the resulting sorted array in the same column of the matrix


  return sorted_matrix

# %%
# Sort each column to recover the original order
sorted_matrix = sort_columns_insertion_sort(matrix)

# Display sorted matrix as an image
plt.imshow(sorted_matrix, cmap='jet')
plt.colorbar()
plt.show()
